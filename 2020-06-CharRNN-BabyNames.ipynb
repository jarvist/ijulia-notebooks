# %%
# A Char RNN (LSTM) baby name generator
# Adapted from: 
#     https://github.com/FluxML/model-zoo/tree/master/text/char-rnn
#
# In no way an original idea! 
# I had implemented this with a set of Norse names back in 2018, but I've lost that training data.
# So I redid it with the list of names from :- 
#     http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/
#
# Andrej Karpathy (I think) probably did the original work. Certainly his names seem much more real:
#     https://boingboing.net/2016/05/06/baby-names-generated-by-a-neur.html
# 
# I like these fairly wrong / more randomised names, as I think they can be a good 
# jumping off point for then your actual human intelligence to make some sense of it!

# %%
using Flux
using Flux: onehot, chunk, batchseq, throttle, logitcrossentropy
using StatsBase: wsample
using Base.Iterators: partition
using Parameters: @with_kw

# Hyperparameter arguments 
@with_kw mutable struct Args
    lr::Float64 = 1e-2	# Learning rate
    seqlen::Int = 50	# Length of batchseqences
    nbatch::Int = 50	# number of batches text is divided into
    throttle::Int = 3	# Throttle timeout
end

function getdata(args; text=nothing)
    # an array of all unique characters
    alphabet = [unique(text)..., '_']
    
    text = map(ch -> onehot(ch, alphabet), text)
    stop = onehot('_', alphabet)

    N = length(alphabet)
    
    # Partitioning the data as sequence of batches, which are then collected as array of batches
    Xs = collect(partition(batchseq(chunk(text, args.nbatch), stop), args.seqlen))
    Ys = collect(partition(batchseq(chunk(text[2:end], args.nbatch), stop), args.seqlen))

    return Xs, Ys, N, alphabet
end

# Function to construct model
function build_model(N)
    return Chain(
            LSTM(N, 128),
            LSTM(128, 128),
            Dense(128, N))
end 

function train(text, nsteps; kws...)
    # Initialize the parameters
    args = Args(; kws...)
    
    # Get Data
    Xs, Ys, N, alphabet = getdata(args, text=text)

    # Constructing Model
    m = build_model(N)

    function loss(xs, ys)
      l = sum(logitcrossentropy.(m.(xs), ys))
      return l
    end
    
    ## Training
    opt = ADAM(args.lr)
    tx, ty = (Xs[5], Ys[5])
    evalcb = () -> @show loss(tx, ty)
    for i = 1:nsteps
        Flux.train!(loss, params(m), zip(Xs, Ys), opt, cb = throttle(evalcb, args.throttle))
    end
    return m, alphabet
end

# Sampling
function sample(m, alphabet, len; seed="")
    m = cpu(m)
    Flux.reset!(m)
    buf = IOBuffer()
    if seed == ""
        seed = string(rand(alphabet))
    end
    write(buf, seed)
    c = wsample(alphabet, softmax(m.(map(c -> onehot(c, alphabet), collect(seed)))[end]))
    for i = 1:len
        write(buf, c)
        c = wsample(alphabet, softmax(m(onehot(c, alphabet))))
    end
    return String(take!(buf))
end
# Out:
# sample (generic function with 1 method)

# %%
cd(@__DIR__)
isfile("male.txt") ||
    download("http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/male.txt","male.txt")
male=collect(string(readlines("male.txt",keep=true)[7:end]...))

isfile("female.txt") ||
    download("http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/female.txt","female.txt")
female=collect(string(readlines("female.txt",keep=true)[7:end]...))

names=vcat(male,female)
length(names)
# Out:
# 55869

# %%
# I forgot to @time this training, but I think it was around ~5 minutes on 1CPU of a 2016 MacBook Pro
m, alphabet = train(names, 100)
sample(m, alphabet, 10000) |> println
# Out:
# loss(tx, ty) = 173.24821f0
# loss(tx, ty) = 160.78125f0
# loss(tx, ty) = 159.0167f0
# loss(tx, ty) = 156.72714f0
# loss(tx, ty) = 153.3975f0
# loss(tx, ty) = 150.32512f0
# loss(tx, ty) = 144.5955f0
# loss(tx, ty) = 139.16145f0
# loss(tx, ty) = 134.97668f0
# loss(tx, ty) = 132.0291f0
# loss(tx, ty) = 135.619f0
# loss(tx, ty) = 136.07945f0
# loss(tx, ty) = 130.47249f0
# loss(tx, ty) = 130.97147f0
# loss(tx, ty) = 130.43753f0
# loss(tx, ty) = 129.66972f0
# loss(tx, ty) = 132.54782f0
# loss(tx, ty) = 130.30905f0
# loss(tx, ty) = 130.32872f0
# loss(tx, ty) = 134.45042f0
# loss(tx, ty) = 136.48637f0
# loss(tx, ty) = 130.51817f0
# loss(tx, ty) = 128.08492f0
# loss(tx, ty) = 127.74405f0
# loss(tx, ty) = 128.09514f0
# loss(tx, ty) = 130.36101f0
# loss(tx, ty) = 128.12236f0
# loss(tx, ty) = 128.42017f0
# loss(tx, ty) = 128.3154f0
# loss(tx, ty) = 127.52186f0
# loss(tx, ty) = 125.74154f0
# loss(tx, ty) = 127.91339f0
# loss(tx, ty) = 126.26141f0
# loss(tx, ty) = 128.44533f0
# loss(tx, ty) = 127.21608f0
# loss(tx, ty) = 127.09291f0
# loss(tx, ty) = 125.93344f0
# loss(tx, ty) = 125.895584f0
# loss(tx, ty) = 125.03284f0
# loss(tx, ty) = 126.09271f0
# loss(tx, ty) = 124.84442f0
# loss(tx, ty) = 126.48116f0
# loss(tx, ty) = 124.424034f0
# loss(tx, ty) = 125.58121f0
# loss(tx, ty) = 126.28527f0
# loss(tx, ty) = 125.564766f0
# loss(tx, ty) = 124.45143f0
# loss(tx, ty) = 124.52545f0
# loss(tx, ty) = 123.66959f0
# loss(tx, ty) = 124.82952f0
# loss(tx, ty) = 123.892944f0
# loss(tx, ty) = 122.410225f0
# loss(tx, ty) = 122.850105f0
# loss(tx, ty) = 124.40264f0
# loss(tx, ty) = 125.92918f0
# loss(tx, ty) = 122.25544f0
# loss(tx, ty) = 127.09083f0
# loss(tx, ty) = 124.671715f0
# loss(tx, ty) = 127.33685f0
# loss(tx, ty) = 124.69779f0
# loss(tx, ty) = 126.213394f0
# loss(tx, ty) = 125.589905f0
# loss(tx, ty) = 124.19912f0
# loss(tx, ty) = 123.974045f0
# loss(tx, ty) = 122.85269f0
# loss(tx, ty) = 122.97972f0
# loss(tx, ty) = 120.9605f0
# loss(tx, ty) = 125.62327f0
# loss(tx, ty) = 123.923004f0
# loss(tx, ty) = 123.2387f0
# loss(tx, ty) = 125.189125f0
# loss(tx, ty) = 124.160446f0
# loss(tx, ty) = 123.4116f0
# loss(tx, ty) = 124.41916f0
# loss(tx, ty) = 123.73923f0
# loss(tx, ty) = 124.99924f0
# loss(tx, ty) = 122.9319f0
# loss(tx, ty) = 125.54826f0
# loss(tx, ty) = 124.3722f0
# loss(tx, ty) = 124.52165f0
# loss(tx, ty) = 124.527214f0
# loss(tx, ty) = 125.983574f0
# loss(tx, ty) = 126.00082f0
# loss(tx, ty) = 124.62314f0
# loss(tx, ty) = 124.613266f0
# loss(tx, ty) = 124.39977f0
# loss(tx, ty) = 123.94929f0
# loss(tx, ty) = 125.3348f0
# loss(tx, ty) = 124.426254f0
# loss(tx, ty) = 123.26311f0
# loss(tx, ty) = 128.09401f0
# loss(tx, ty) = 124.43935f0
# loss(tx, ty) = 123.70382f0
# loss(tx, ty) = 127.20671f0
# loss(tx, ty) = 124.01848f0
# loss(tx, ty) = 122.61844f0
# loss(tx, ty) = 125.20125f0
# loss(tx, ty) = 124.12925f0
# loss(tx, ty) = 123.45289f0
# loss(tx, ty) = 125.14632f0
# loss(tx, ty) = 123.74388f0
# loss(tx, ty) = 124.32816f0
# loss(tx, ty) = 125.9352f0
# loss(tx, ty) = 124.57488f0
# loss(tx, ty) = 123.998856f0
# loss(tx, ty) = 127.28359f0
# loss(tx, ty) = 124.39737f0
# loss(tx, ty) = 123.49384f0
# loss(tx, ty) = 126.026535f0
# loss(tx, ty) = 123.40561f0
# loss(tx, ty) = 122.92144f0
# loss(tx, ty) = 123.98143f0
# loss(tx, ty) = 123.7121f0
# loss(tx, ty) = 122.32283f0
# loss(tx, ty) = 126.30057f0
# loss(tx, ty) = 122.95239f0
# loss(tx, ty) = 122.31842f0
# loss(tx, ty) = 123.75706f0
# loss(tx, ty) = 122.42079f0
# loss(tx, ty) = 121.38071f0
# loss(tx, ty) = 125.29142f0
# loss(tx, ty) = 122.28496f0
# loss(tx, ty) = 121.73382f0
# loss(tx, ty) = 123.16611f0
# loss(tx, ty) = 122.40086f0
# loss(tx, ty) = 121.704155f0
# loss(tx, ty) = 124.63086f0
# loss(tx, ty) = 123.48082f0
# loss(tx, ty) = 122.6193f0
# loss(tx, ty) = 123.520035f0
# loss(tx, ty) = 123.51051f0
# loss(tx, ty) = 121.94226f0
# loss(tx, ty) = 124.490036f0
# loss(tx, ty) = 123.33972f0
# loss(tx, ty) = 122.73641f0
# loss(tx, ty) = 123.19047f0
# loss(tx, ty) = 122.71107f0
# loss(tx, ty) = 122.03188f0
# loss(tx, ty) = 123.60153f0
# loss(tx, ty) = 123.314804f0
# loss(tx, ty) = 122.59162f0
# loss(tx, ty) = 122.743576f0
# loss(tx, ty) = 122.88466f0
# loss(tx, ty) = 121.183235f0
# loss(tx, ty) = 122.82129f0
# loss(tx, ty) = 122.46751f0
# loss(tx, ty) = 120.57976f0
# loss(tx, ty) = 124.37467f0
# loss(tx, ty) = 122.772675f0
# loss(tx, ty) = 122.87993f0
# loss(tx, ty) = 120.87322f0
# loss(tx, ty) = 122.33862f0
# loss(tx, ty) = 121.87793f0
# loss(tx, ty) = 122.28405f0
# loss(tx, ty) = 120.06676f0
# loss(tx, ty) = 122.212776f0
# loss(tx, ty) = 121.69827f0
# loss(tx, ty) = 120.07051f0
# loss(tx, ty) = 122.080956f0
# loss(tx, ty) = 121.56653f0
# loss(tx, ty) = 119.723366f0
# loss(tx, ty) = 122.58945f0
# loss(tx, ty) = 121.45144f0
# loss(tx, ty) = 120.15846f0
# loss(tx, ty) = 122.178444f0
# loss(tx, ty) = 121.27453f0
# loss(tx, ty) = 119.86136f0
# loss(tx, ty) = 122.0773f0
# loss(tx, ty) = 120.8436f0
# loss(tx, ty) = 119.835495f0
# loss(tx, ty) = 121.94958f0
# loss(tx, ty) = 120.45965f0
# loss(tx, ty) = 120.158005f0
# loss(tx, ty) = 121.46306f0
# loss(tx, ty) = 120.74882f0
# loss(tx, ty) = 119.86674f0
# loss(tx, ty) = 120.95972f0
# loss(tx, ty) = 120.33812f0
# loss(tx, ty) = 119.92481f0
# loss(tx, ty) = 121.60234f0
# loss(tx, ty) = 120.02729f0
# loss(tx, ty) = 119.40387f0
# loss(tx, ty) = 120.90112f0
# loss(tx, ty) = 121.000786f0
# loss(tx, ty) = 120.32444f0
# loss(tx, ty) = 121.25017f0
# loss(tx, ty) = 120.49859f0
# loss(tx, ty) = 120.159676f0
# loss(tx, ty) = 121.02113f0
# loss(tx, ty) = 120.809395f0
# loss(tx, ty) = 119.51518f0
# loss(tx, ty) = 122.15517f0
# loss(tx, ty) = 120.88616f0
# loss(tx, ty) = 120.00006f0
# loss(tx, ty) = 120.54469f0
# loss(tx, ty) = 119.94691f0
# loss(tx, ty) = 123.407585f0
# loss(tx, ty) = 120.67121f0
# loss(tx, ty) = 119.379486f0
# loss(tx, ty) = 120.973404f0
# loss(tx, ty) = 120.060326f0
# loss(tx, ty) = 119.030655f0
# loss(tx, ty) = 120.593864f0
# loss(tx, ty) = 119.346855f0
# loss(tx, ty) = 122.64875f0
# loss(tx, ty) = 120.65919f0
# loss(tx, ty) = 119.73447f0
# loss(tx, ty) = 121.094826f0
# loss(tx, ty) = 120.15427f0
# loss(tx, ty) = 121.303024f0
# loss(tx, ty) = 120.69654f0
# loss(tx, ty) = 121.03825f0
# loss(tx, ty) = 122.70504f0
# loss(tx, ty) = 121.678925f0
# loss(tx, ty) = 119.625084f0
# loss(tx, ty) = 122.07073f0
# loss(tx, ty) = 120.60777f0
# loss(tx, ty) = 119.50391f0
# loss(tx, ty) = 123.42469f0
# loss(tx, ty) = 120.648926f0
# loss(tx, ty) = 119.96926f0
# loss(tx, ty) = 121.36247f0
# loss(tx, ty) = 119.406525f0
# loss(tx, ty) = 122.039116f0
# loss(tx, ty) = 120.77412f0
# loss(tx, ty) = 119.238846f0
# loss(tx, ty) = 121.72403f0
# loss(tx, ty) = 120.67941f0
# loss(tx, ty) = 119.74027f0
# loss(tx, ty) = 122.01434f0
# loss(tx, ty) = 120.61877f0
# loss(tx, ty) = 120.56792f0
# loss(tx, ty) = 122.52314f0
# loss(tx, ty) = 121.48995f0
# loss(tx, ty) = 120.85564f0
# loss(tx, ty) = 121.37729f0
# loss(tx, ty) = 120.92588f0
# loss(tx, ty) = 119.58575f0
# loss(tx, ty) = 120.958305f0
# loss(tx, ty) = 119.98782f0
# loss(tx, ty) = 119.97779f0
# loss(tx, ty) = 120.1677f0
# loss(tx, ty) = 120.17088f0
# loss(tx, ty) = 124.05437f0
# loss(tx, ty) = 122.30121f0
# loss(tx, ty) = 120.413536f0
# loss(tx, ty) = 120.88613f0
# loss(tx, ty) = 121.342f0
# loss(tx, ty) = 120.18243f0
# loss(tx, ty) = 122.01763f0
# loss(tx, ty) = 119.966385f0
# loss(tx, ty) = 121.656235f0
# loss(tx, ty) = 120.245804f0
# loss(tx, ty) = 121.924805f0
# loss(tx, ty) = 124.372795f0
# loss(tx, ty) = 120.59437f0
# loss(tx, ty) = 120.57954f0
# loss(tx, ty) = 122.5096f0
# loss(tx, ty) = 121.80185f0
# loss(tx, ty) = 120.26268f0
# loss(tx, ty) = 123.74077f0
# loss(tx, ty) = 121.41843f0
# loss(tx, ty) = 120.584015f0
# loss(tx, ty) = 123.07407f0
# loss(tx, ty) = 121.00474f0
# loss(tx, ty) = 120.678535f0
# loss(tx, ty) = 119.42994f0
# loss(tx, ty) = 119.32415f0
# loss(tx, ty) = 122.43458f0
# loss(tx, ty) = 119.46426f0
# loss(tx, ty) = 119.42521f0
# loss(tx, ty) = 123.90548f0
#  Ch
# Dermdnnnnr
# Esara
# Blrellnth
# Auly
# Bsivulsttredia
# J
# Anciyl
# Merrylinstanl
# VavyllMan
# ElElamdtl
# Luen
# Allkonsmiasilnsta
# Btron
# Yira
# Rtnna
# Dalicinnanne
# Letsilis
# Vellil
# Moxamatroran
# Cudulll
# Avia
# Camena
# Marsrria
# Delans
# Shoricke
# ChnclricennnrienZele
# Halanzlx
# Ald
# Oxrtfon
# Mallaamorsl
# Inlfefbch
# RornemenllWendfadhalGetl
# Ch
# Albevornen
# Su
# Berncasttmicykee
# M
# Arebalrtlyl
# Sanclllle
# Brlbpay
# Leidarnkororanauarmlle
# Kanraorteressringdngpnlsr
# Tanveann
# Gers
# ElellellarodnnllUlNangan
# Ttyr
# Shimikkhln
# Enlcma
# Ma
# MenfPe
# Zarrissticty
# Ch
# Rellelisle
# Ezons
# Ronnlandrl-Jenn
# Anry
# Damonrrcll
# Darblrarthsh
# Kanu
# Eliuethersnndreraxika
# Bha
# Gla
# Aeldlln
# Remirnmrle
# Urllllinanvan
# Dieei
# Ch
# VactoudlsellsallKea
# Till
# Cantu
# D
# Coll
# Elta
# Derbrsglargnislk
# Sabicbeo
# Zerncash
# Jomyny
# Duddtlaxanr
# Hant
# E
# Barnrle
# En
# LillAdrclllsrin
# DeckblevanaredlranllHepbvan
# Cerld
# Riaraliele
# Jaorararmde
# Vaci
# Estheldnm
# Advardid
# Scisds
# Rillil
# S
# Anrekh
# Errilllpmed
# Sik
# Norfersan
# Terlarod
# Hellemrsa
# Sensosterml
# PevogmelWastyrka
# Nakhkrvenelnlhn
# Meralvre
# S
# Sargllilaumllst
# Tarnjensikemlnslenssie
# Gaktlnl
# Atin
# Darie
# Srullnalmumln
# Anlmacra
# Ris
# Vikkyr
# OssellYet
# Anje
# Ifpe
# Pallee
# Rersll
# Elrnda
# Evaduntta
# ln-Pellinnr
# Doka
# La Fickann
# Aerpina
# Ca
# Mayke
# Tan
# Gasvesn
# Ast
# Deppqerngnenann
# Edg_erin
# Adrmpqrqmcbminal
# Marirs
# Etvwrrararin
# Rowrolerelelychse
# Eleollie
# Asctlnssa
# Hicellorenasarurrl
# S
# Gorsly
# Derl
# Me
# Fricie
# T
# Rann
# Bopulibugyn
# Amilsonertah
# Darietunrn
# Gkanddbstielanomlvepl
# Usvanerndhra
# Ilike
# Asse
# Sansorad
# Oricagltlginn
# Tat
# Ru
# Mor
# Turnachnsttrolnch
# Esvunira
# Jell
# Danlezst
# MoitrlllVa
# Sl
# Je
# Laerwlji
# Evew
# RollPrre
# Jach
# Aillriprma
# Cumlmlaraen
# Vassanlrrth
# Cestisielussa
# Sherrnllgethnnla
# Walullnerbyr
# Adlinesatriilivinsh
# Mande
# Berrarg
# Resta
# Reolyvie
# Jilnl
# Shioesadya
# Dewnith
# Hanby
# AratotllKanvet
# ElllF
# Allsm
# Darriponia
# Ha
# Mars
# Aral
# Jarnetkiniellilya
# FroszallHenlSastine
# Al
# Puvemercy
# Yhineudy
# Olmlcu
# Jie
# Win
# Gebennndesic
# Skerie
# Intt
# Daxyy
# Rerrih
# Tus
# Breselanin
# Darlldtrar
# SnemyriranlculOnnlHuarbilllsa
# Orrtenlan
# Rhisne
# Bacinnararlegdarynvodbll
# Kenfeo
# Brenvill
# Agyinorthry
# Lorgcheflyseg
# Mers
# Oshakh
# Nianrsminninvenee
# Harchngn
# Iesa
# Pen
# Unstiwls
# Kespihepya
# Stanbamricldin
# Arlss
# Racullit
# Vin
# Virsld
# Myma
# Warerrarssanvell
# Shrqelllrillellenn
# Mnnrorgn
# Mandn
# Romienshrngbesra
# N
# Araidttta
# Ensnich
# Yardeu
# Calpio
# Clerendwbrontlie
# Hera
# Grores
# Julphy
# Gosthephnnmra
# Sharorarald
# Courrils
# Si
# Tray
# Brrrmlna
# ElnahriollEdoliranwelrngncten
# T
# Maikes
# Frid
# Adina
# Shnorra
# So
# Gatrinnnaldt
# Tunn
# Wir
# Mill
# Stersanelro
# OlnsilrgAvlbrgdrsa
# AreceelkerFegsrrichi
# Reld
# J
# SassrlW
# Malriranrrst
# NertlvemllJtrlfttonatta
# Hernnd
# Hath
# Arrit
# Saana
#
# Harl
# Bhecia
# Evrtldan
# Ple
# Reletld

# %%
m, alphabet = train(M)
sample(m, alphabet, 1000) |> println
# Out:
# loss(tx, ty) = 174.7434f0
# loss(tx, ty) = 163.19757f0
# loss(tx, ty) = 162.01944f0
# loss(tx, ty) = 161.3833f0
# loss(tx, ty) = 159.84792f0
# loss(tx, ty) = 162.13979f0
# loss(tx, ty) = 162.96867f0
# loss(tx, ty) = 162.30132f0
# loss(tx, ty) = 161.68213f0
# loss(tx, ty) = 161.45326f0
# loss(tx, ty) = 159.66147f0
# loss(tx, ty) = 157.4465f0
# loss(tx, ty) = 156.85132f0
# loss(tx, ty) = 151.71425f0
# loss(tx, ty) = 147.25282f0
# loss(tx, ty) = 143.75894f0
# loss(tx, ty) = 141.19958f0
# loss(tx, ty) = 138.89828f0
# loss(tx, ty) = 137.14867f0
# loss(tx, ty) = 135.71844f0
# loss(tx, ty) = 135.0299f0
# loss(tx, ty) = 133.69594f0
# loss(tx, ty) = 131.97601f0
# loss(tx, ty) = 131.41594f0
# loss(tx, ty) = 130.62589f0
# loss(tx, ty) = 130.16699f0
# loss(tx, ty) = 130.06006f0
# loss(tx, ty) = 129.6974f0
# loss(tx, ty) = 129.00066f0
# loss(tx, ty) = 128.92249f0
# loss(tx, ty) = 128.8132f0
# loss(tx, ty) = 128.09833f0
# loss(tx, ty) = 128.2645f0
# loss(tx, ty) = 127.211655f0
# loss(tx, ty) = 127.98432f0
# loss(tx, ty) = 128.33676f0
# loss(tx, ty) = 128.86119f0
# loss(tx, ty) = 127.60475f0
# loss(tx, ty) = 129.46655f0
# loss(tx, ty) = 128.82188f0
# loss(tx, ty) = 127.75992f0
# loss(tx, ty) = 129.95972f0
# loss(tx, ty) = 131.23364f0
# loss(tx, ty) = 130.58585f0
# loss(tx, ty) = 129.48825f0
# loss(tx, ty) = 129.40044f0
# loss(tx, ty) = 129.18153f0
# loss(tx, ty) = 130.06487f0
# loss(tx, ty) = 129.0629f0
# loss(tx, ty) = 127.75325f0
# loss(tx, ty) = 127.59982f0
# loss(tx, ty) = 127.12685f0
# loss(tx, ty) = 127.49196f0
# loss(tx, ty) = 127.50741f0
# loss(tx, ty) = 130.373f0
# loss(tx, ty) = 127.67642f0
# loss(tx, ty) = 127.17493f0
# loss(tx, ty) = 127.255516f0
# loss(tx, ty) = 125.620674f0
# loss(tx, ty) = 126.02051f0
# loss(tx, ty) = 125.84903f0
# loss(tx, ty) = 125.999214f0
# loss(tx, ty) = 126.58655f0
# loss(tx, ty) = 126.411835f0
# loss(tx, ty) = 126.07142f0
# loss(tx, ty) = 126.23638f0
# loss(tx, ty) = 126.23567f0
# loss(tx, ty) = 125.12585f0
# loss(tx, ty) = 125.96036f0
# loss(tx, ty) = 125.7704f0
# loss(tx, ty) = 125.99689f0
# loss(tx, ty) = 125.078094f0
# loss(tx, ty) = 125.32578f0
# loss(tx, ty) = 125.04862f0
# loss(tx, ty) = 125.532196f0
# loss(tx, ty) = 126.49099f0
# loss(tx, ty) = 126.795166f0
# loss(tx, ty) = 127.34742f0
# loss(tx, ty) = 127.06782f0
# loss(tx, ty) = 126.8893f0
# loss(tx, ty) = 126.39788f0
# loss(tx, ty) = 126.95569f0
# loss(tx, ty) = 127.32094f0
# loss(tx, ty) = 128.25137f0
# loss(tx, ty) = 127.65628f0
# loss(tx, ty) = 127.742714f0
# loss(tx, ty) = 126.52914f0
# loss(tx, ty) = 126.35271f0
# loss(tx, ty) = 126.33496f0
# loss(tx, ty) = 125.673676f0
# loss(tx, ty) = 125.926834f0
# loss(tx, ty) = 125.41982f0
# loss(tx, ty) = 127.16231f0
# loss(tx, ty) = 125.64972f0
# loss(tx, ty) = 125.53546f0
# loss(tx, ty) = 125.64648f0
# loss(tx, ty) = 125.46922f0
# loss(tx, ty) = 125.29672f0
# loss(tx, ty) = 125.31153f0
# loss(tx, ty) = 125.18898f0
# loss(tx, ty) = 125.5332f0
# Qm
# Geh
# Aldr
# C
# Lorigilwbtk
# Colney
# Mahaz
# Otuge
# Halggonnhintniy
# Tekarsaeguritkene
# Shrebldin
# An
# Gackenbono
# Bilfin
# Margn
# Anthbacitt
# Are
# Tregol
# Shadbaafa
# Liny
# rrie
# Prntow
# Bivamustglinginoshrokee
# Dintorrt
# Shailal
# Masto
# Shitikerit
# Dalntkenri
# Heetyi
# Jonhranghaher
# Hen
# Dajinolbelerllop
# Z
# Zernrey
# Kerlanifaioy
# Bied
# Gmalrardune
# Fuberem
# C
# Gie
# Cha
# Ar
# Hiunn
# Mallrik
# Jarlto
# Caem
# Raop
# Vhonul
# Punhmecon
# Hanf
# Burlel
# Abuevilcrmrifterrn
# S
# Teriomythoie
# Panlmno
# Bon
# S
# Jeo
# Waviraf
# Tulnedrldr
#
# Jarrrasnckarban
# Aodianthavormu
# Deillorin
# N
# S
# Jolmenewy
# Edthdosranrshan
# Kunka
# Estelcowerigre
# Milmitarl
# Lenhensdtthapesarrureme
# Vantkin
# Whaerlrilke
# Giliablinlrolltelemienesy
# Balverremy
# Her
# Kdleg
# Ginfonawenonaheralen
# Dhrhan
# Lurnuncosancelilapon
# Ies
# Thorgrarce
# Dienkantrkeunthe
# Menn
# Jiriefindrrtthar
# Cay
# Derrelolel
# An
# Jatthernhtan
# Le
# Wartkii
# n
# Skod
# Tanpmikay
# Pa
# Id
# Fun
# sherthapaie
# Reon
# Dolarr
# te
# Rudlolern
# Pardiseona
# Lorily
# Monre
# Sacuran
# Handy
# Palla
# Luhggrmrditfolnlonledaratelafedllvudrog
# Rolrt
# Bi_veri
# Ivarltris
# Red
# Ramy
# Bay
# Rishahlo

# %%
# around ~15 minutes on 1CPU of a 2016 MacBook Pro
@time m, alphabet = train(names, 100)
sample(m, alphabet, 10000) |> println
# Out:
# loss(tx, ty) = 173.4664f0
# loss(tx, ty) = 160.2932f0
# loss(tx, ty) = 161.3826f0
# loss(tx, ty) = 159.94414f0
# loss(tx, ty) = 160.37593f0
# loss(tx, ty) = 158.0656f0
# loss(tx, ty) = 156.65764f0
# loss(tx, ty) = 154.80614f0
# loss(tx, ty) = 145.65611f0
# loss(tx, ty) = 140.90274f0
# loss(tx, ty) = 140.86984f0
# loss(tx, ty) = 135.07718f0
# loss(tx, ty) = 137.05408f0
# loss(tx, ty) = 135.2085f0
# loss(tx, ty) = 132.35774f0
# loss(tx, ty) = 133.4976f0
# loss(tx, ty) = 132.9737f0
# loss(tx, ty) = 131.45644f0
# loss(tx, ty) = 133.14331f0
# loss(tx, ty) = 130.27876f0
# loss(tx, ty) = 130.05963f0
# loss(tx, ty) = 130.92146f0
# loss(tx, ty) = 132.03603f0
# loss(tx, ty) = 129.6431f0
# loss(tx, ty) = 131.69891f0
# loss(tx, ty) = 129.62355f0
# loss(tx, ty) = 130.14714f0
# loss(tx, ty) = 129.45172f0
# loss(tx, ty) = 129.3935f0
# loss(tx, ty) = 125.777405f0
# loss(tx, ty) = 128.34616f0
# loss(tx, ty) = 128.09167f0
# loss(tx, ty) = 124.743904f0
# loss(tx, ty) = 129.73082f0
# loss(tx, ty) = 128.80675f0
# loss(tx, ty) = 124.876526f0
# loss(tx, ty) = 126.620636f0
# loss(tx, ty) = 127.65142f0
# loss(tx, ty) = 124.97509f0
# loss(tx, ty) = 129.21803f0
# loss(tx, ty) = 127.921455f0
# loss(tx, ty) = 125.69792f0
# loss(tx, ty) = 127.67298f0
# loss(tx, ty) = 127.683876f0
# loss(tx, ty) = 124.64615f0
# loss(tx, ty) = 126.593216f0
# loss(tx, ty) = 127.45876f0
# loss(tx, ty) = 123.65559f0
# loss(tx, ty) = 125.19118f0
# loss(tx, ty) = 126.946655f0
# loss(tx, ty) = 123.39789f0
# loss(tx, ty) = 125.33899f0
# loss(tx, ty) = 126.47949f0
# loss(tx, ty) = 123.98732f0
# loss(tx, ty) = 126.436646f0
# loss(tx, ty) = 126.687096f0
# loss(tx, ty) = 124.43504f0
# loss(tx, ty) = 124.75784f0
# loss(tx, ty) = 126.59677f0
# loss(tx, ty) = 123.76383f0
# loss(tx, ty) = 125.80162f0
# loss(tx, ty) = 126.00473f0
# loss(tx, ty) = 122.867905f0
# loss(tx, ty) = 124.58805f0
# loss(tx, ty) = 125.95398f0
# loss(tx, ty) = 121.537704f0
# loss(tx, ty) = 125.59741f0
# loss(tx, ty) = 124.5704f0
# loss(tx, ty) = 122.1605f0
# loss(tx, ty) = 123.33686f0
# loss(tx, ty) = 123.63797f0
# loss(tx, ty) = 122.93035f0
# loss(tx, ty) = 124.34286f0
# loss(tx, ty) = 124.17922f0
# loss(tx, ty) = 121.520485f0
# loss(tx, ty) = 123.41888f0
# loss(tx, ty) = 123.36846f0
# loss(tx, ty) = 121.62377f0
# loss(tx, ty) = 123.723335f0
# loss(tx, ty) = 124.02638f0
# loss(tx, ty) = 122.049f0
# loss(tx, ty) = 124.23212f0
# loss(tx, ty) = 124.53468f0
# loss(tx, ty) = 122.054085f0
# loss(tx, ty) = 123.781044f0
# loss(tx, ty) = 124.48636f0
# loss(tx, ty) = 121.60251f0
# loss(tx, ty) = 123.49857f0
# loss(tx, ty) = 124.67255f0
# loss(tx, ty) = 121.53101f0
# loss(tx, ty) = 124.698f0
# loss(tx, ty) = 125.90839f0
# loss(tx, ty) = 123.62256f0
# loss(tx, ty) = 123.475685f0
# loss(tx, ty) = 124.566284f0
# loss(tx, ty) = 122.24238f0
# loss(tx, ty) = 123.60037f0
# loss(tx, ty) = 124.39935f0
# loss(tx, ty) = 122.41388f0
# loss(tx, ty) = 123.58496f0
# loss(tx, ty) = 124.584145f0
# loss(tx, ty) = 122.51116f0
# loss(tx, ty) = 123.88824f0
# loss(tx, ty) = 124.27556f0
# loss(tx, ty) = 122.50869f0
# loss(tx, ty) = 123.72239f0
# loss(tx, ty) = 124.931114f0
# loss(tx, ty) = 122.31517f0
# loss(tx, ty) = 123.75626f0
# loss(tx, ty) = 124.20748f0
# loss(tx, ty) = 122.45887f0
# loss(tx, ty) = 123.475914f0
# loss(tx, ty) = 124.347984f0
# loss(tx, ty) = 121.69639f0
# loss(tx, ty) = 123.25314f0
# loss(tx, ty) = 124.839386f0
# loss(tx, ty) = 122.09066f0
# loss(tx, ty) = 124.938286f0
# loss(tx, ty) = 125.432014f0
# loss(tx, ty) = 121.962234f0
# loss(tx, ty) = 124.21957f0
# loss(tx, ty) = 124.39824f0
# loss(tx, ty) = 122.31359f0
# loss(tx, ty) = 123.60084f0
# loss(tx, ty) = 125.21051f0
# loss(tx, ty) = 121.57852f0
# loss(tx, ty) = 122.9897f0
# loss(tx, ty) = 125.49863f0
# loss(tx, ty) = 121.90599f0
# loss(tx, ty) = 123.272644f0
# loss(tx, ty) = 124.02744f0
# loss(tx, ty) = 121.54608f0
# loss(tx, ty) = 123.92929f0
# loss(tx, ty) = 123.88841f0
# loss(tx, ty) = 120.78617f0
# loss(tx, ty) = 123.79886f0
# loss(tx, ty) = 124.37928f0
# loss(tx, ty) = 120.54687f0
# loss(tx, ty) = 123.42259f0
# loss(tx, ty) = 123.53569f0
# loss(tx, ty) = 120.85966f0
# loss(tx, ty) = 121.91273f0
# loss(tx, ty) = 123.30202f0
# loss(tx, ty) = 120.322296f0
# loss(tx, ty) = 122.05516f0
# loss(tx, ty) = 122.989784f0
# loss(tx, ty) = 119.54629f0
# loss(tx, ty) = 120.876175f0
# loss(tx, ty) = 122.131874f0
# loss(tx, ty) = 119.572495f0
# loss(tx, ty) = 121.391815f0
# loss(tx, ty) = 122.27851f0
# loss(tx, ty) = 119.33184f0
# loss(tx, ty) = 120.93345f0
# loss(tx, ty) = 122.50372f0
# loss(tx, ty) = 120.31511f0
# loss(tx, ty) = 122.93549f0
# loss(tx, ty) = 124.00425f0
# loss(tx, ty) = 121.300186f0
# loss(tx, ty) = 122.5785f0
# loss(tx, ty) = 122.81919f0
# loss(tx, ty) = 120.39751f0
# loss(tx, ty) = 121.70363f0
# loss(tx, ty) = 121.609276f0
# loss(tx, ty) = 119.99732f0
# loss(tx, ty) = 121.65281f0
# loss(tx, ty) = 121.668045f0
# loss(tx, ty) = 119.84507f0
# loss(tx, ty) = 123.99498f0
# loss(tx, ty) = 125.18864f0
# loss(tx, ty) = 121.6406f0
# loss(tx, ty) = 122.17254f0
# loss(tx, ty) = 123.25888f0
# loss(tx, ty) = 120.83594f0
# loss(tx, ty) = 123.61548f0
# loss(tx, ty) = 123.89809f0
# loss(tx, ty) = 120.64371f0
# loss(tx, ty) = 122.3794f0
# loss(tx, ty) = 123.78913f0
# loss(tx, ty) = 121.485535f0
# loss(tx, ty) = 123.60441f0
# loss(tx, ty) = 123.50863f0
# loss(tx, ty) = 119.974556f0
# loss(tx, ty) = 122.52255f0
# loss(tx, ty) = 123.686615f0
# loss(tx, ty) = 119.85527f0
# loss(tx, ty) = 120.82435f0
# loss(tx, ty) = 122.73398f0
# loss(tx, ty) = 120.06864f0
# loss(tx, ty) = 123.23994f0
# loss(tx, ty) = 122.0431f0
# loss(tx, ty) = 119.27893f0
# loss(tx, ty) = 122.579185f0
# loss(tx, ty) = 122.59989f0
# loss(tx, ty) = 119.60781f0
# loss(tx, ty) = 121.83125f0
# loss(tx, ty) = 122.89225f0
# loss(tx, ty) = 119.668526f0
# loss(tx, ty) = 120.03183f0
# loss(tx, ty) = 121.88773f0
# loss(tx, ty) = 118.66051f0
# loss(tx, ty) = 119.578186f0
# loss(tx, ty) = 120.45842f0
# loss(tx, ty) = 118.63289f0
# loss(tx, ty) = 119.26617f0
# loss(tx, ty) = 120.65807f0
# loss(tx, ty) = 117.91323f0
# loss(tx, ty) = 120.16933f0
# loss(tx, ty) = 120.89734f0
# loss(tx, ty) = 118.12363f0
# loss(tx, ty) = 121.14795f0
# loss(tx, ty) = 120.83621f0
# loss(tx, ty) = 119.062836f0
# loss(tx, ty) = 122.06593f0
# loss(tx, ty) = 121.64861f0
# loss(tx, ty) = 119.70563f0
# loss(tx, ty) = 122.654655f0
# loss(tx, ty) = 121.417f0
# loss(tx, ty) = 119.27622f0
# loss(tx, ty) = 122.45314f0
# loss(tx, ty) = 121.59244f0
# loss(tx, ty) = 118.54968f0
# loss(tx, ty) = 122.28069f0
# loss(tx, ty) = 121.913925f0
# loss(tx, ty) = 119.69718f0
# loss(tx, ty) = 122.343864f0
# loss(tx, ty) = 123.61671f0
# loss(tx, ty) = 163.75974f0
# loss(tx, ty) = 131.44797f0
# loss(tx, ty) = 127.752266f0
# loss(tx, ty) = 122.39375f0
# loss(tx, ty) = 122.76946f0
# loss(tx, ty) = 123.72329f0
# loss(tx, ty) = 120.48308f0
# loss(tx, ty) = 121.070045f0
# loss(tx, ty) = 122.771675f0
# loss(tx, ty) = 120.28953f0
# loss(tx, ty) = 120.600685f0
# loss(tx, ty) = 121.894875f0
# loss(tx, ty) = 118.785095f0
# loss(tx, ty) = 119.85822f0
# loss(tx, ty) = 121.345215f0
# loss(tx, ty) = 118.48298f0
# loss(tx, ty) = 119.250626f0
# loss(tx, ty) = 121.51297f0
# loss(tx, ty) = 116.95325f0
# loss(tx, ty) = 118.62109f0
# loss(tx, ty) = 120.54658f0
# loss(tx, ty) = 116.94012f0
# loss(tx, ty) = 119.45792f0
# loss(tx, ty) = 120.06227f0
# loss(tx, ty) = 117.084854f0
# loss(tx, ty) = 119.16722f0
# loss(tx, ty) = 119.882706f0
# loss(tx, ty) = 116.997765f0
# loss(tx, ty) = 119.859764f0
# loss(tx, ty) = 120.493034f0
# loss(tx, ty) = 116.691284f0
# loss(tx, ty) = 118.52622f0
# loss(tx, ty) = 120.39169f0
# loss(tx, ty) = 117.21362f0
# loss(tx, ty) = 119.04696f0
# loss(tx, ty) = 119.93704f0
# loss(tx, ty) = 116.94681f0
# loss(tx, ty) = 118.8529f0
# loss(tx, ty) = 120.412544f0
# loss(tx, ty) = 116.94424f0
# loss(tx, ty) = 118.102234f0
# loss(tx, ty) = 119.795685f0
# loss(tx, ty) = 116.928734f0
# loss(tx, ty) = 118.3128f0
# loss(tx, ty) = 119.77336f0
# loss(tx, ty) = 117.82362f0
# loss(tx, ty) = 119.525505f0
# loss(tx, ty) = 120.596146f0
# loss(tx, ty) = 117.46103f0
# loss(tx, ty) = 118.75972f0
# loss(tx, ty) = 120.85547f0
# loss(tx, ty) = 117.52744f0
# loss(tx, ty) = 117.87734f0
# loss(tx, ty) = 119.62509f0
# loss(tx, ty) = 120.72725f0
# loss(tx, ty) = 121.30437f0
# loss(tx, ty) = 121.0912f0
# loss(tx, ty) = 115.83399f0
# loss(tx, ty) = 118.47302f0
# loss(tx, ty) = 119.12304f0
# loss(tx, ty) = 116.82104f0
# loss(tx, ty) = 118.1278f0
# loss(tx, ty) = 118.05693f0
# loss(tx, ty) = 115.3859f0
# loss(tx, ty) = 117.93576f0
# loss(tx, ty) = 118.727325f0
# loss(tx, ty) = 115.46644f0
# loss(tx, ty) = 117.467155f0
# loss(tx, ty) = 118.87647f0
# loss(tx, ty) = 115.258705f0
# loss(tx, ty) = 117.67935f0
# loss(tx, ty) = 119.520256f0
# loss(tx, ty) = 117.20565f0
# loss(tx, ty) = 121.11519f0
# 1018.929431 seconds (72.26 M allocations: 616.444 GiB, 26.90% gc time)
# 'Poceti
# Kabillelncndieltrrailton
# Ial
# nwes
# Zannscela
# Kennittnr
# Hand
# Edi
# Sumiincy
# Marigymraid
# Alvh
# Darl
# Hynn
# Hud
# Didi
# Shewgigene
# Jenmenar
# Frietca
# Kata
# Lisgvar
# Sinndne
# Bynn
# Ostllangsolrgrens
# Robevev
# Junclflen
# Enasndelette
# Jawelires
# Lannia
# Sarnannnnanleiternnnllllld
# Vamsironmanneaa
# Hun
# Fnssse
# Afsni
# Jadlcia
# Evcalannerlalkd
# Hicvonmelarrn
# Honr
# Kaca
#
# Kosvisdmittardelye
# Sartizellsilin
# Jiannrvassanse
# Denlr
# Dareph
# Jerfn
# SaDu
# Warsa
# Margir
# Jusncheicka
# Minll
# Kath
# Rib
# Nanggotlinnady
# Tha
# Clette
# Sden
# Kel
# Kinnduno-Chrrithe
# Kitwola
# El
# Mellldnlenetlia
# Firigrles
# Kill
# Harylkele
# Kin
# Kartelickepadel
# Shurlanlll
# Crivin
# Nerwenlallmorin
# Bsthn
# Ril
# Dunttlederrerrdry
# Bite
# Maxiala
# Enn
# Stannnckl
# Vilet
# Alannmemrigellarraylanonta___Manlly
# Ill
# Doralkwa
# Faricorle
# Sande
# Rhara
# Irreshincolodordrdfiy
# Marmonnncnnnry
# Dudlbt
# Sirillaterbyduslirimarrelannllllliannn
# Warimemdreraldnscolltheltelyna
# Aynndraerncane
# Morast
# Rerlanbivesa
# Kerrd
# Alemartarda
# Maralutcackckdleap
# Corna
# Kichdrist
#
# Orrorn
# Elenlqnohyla
# Darth
# Rul
# Elnmedbela
# Edlale
# Sle
# Relll
# Shevdyllldy
# Cisserlaerlrsla
# Rol
# Winrurrlnlphalrelchaa
# Rivandslh
# Crorhicsarannneennnnce
# Memm
# Ansshnarart
# Inllellarlisstalka
# Sih
# Sorrda
# Lulhdremlnsa
# Avverdibe
# Roxarishgusjarinnncettenissk
# Pravly
# Kos
# Parilirttsl
# Chiesssikillis
# Han
# Dux
# Vidia
# Kase
# Irrreunnlm
# ndra
# Ruinns
# Chialellalcalldjard
# Shanlesestlijarrallklerslia
# Larlerlhne
# Hensselenmnelh
# Sharsierimralcinchni
# Sorllil
# Vennsa
#
# Marisik
# Rereleselne____Audrikikcealarilliat
# Chrlcilita
#
# Kazriascellmoiinnaphel
# Onieles
# Dardfstanrtosssmarir
# Kri
# Bitranra
# Amnallis
# Sagde
# Estarny
# Volthelma
# Sund
# Herrah
# Evind
# Briranrttice
# Dorwistarlilly
# Dgennss
# Enwthasnareth
# Rehtengalsa
# Ebtranndleie
# Cranmlenrirrlscennbilmelle
# Mad
# Berlyn
# Rus
# Jerrithnevonsorl
# Shie
# Sikbrarn
# Jarildcnshtannttrrinnara
# Reld
# It
# Sannne
# Elmtgolia
# Gien
# Wte
# Marishellda
# Elmiskaknermtannnddarrdra
# Helmia
# Hereiinhansssstennnnnvinlliarburindi
# Sh
# Jar
# El
# Dynnn
# Feraligry
# Hath
# Iskdd
# Warritdwille
# Dice
# Marretta
# Morasvarivenla
# S
# Dus
# Daracallean-Kkelbelrrcie
# Ogree
# Zaxlav
# Crardy
# Jim
# Kranstalysylae
# Maro
# Dodenhasstciaendbbriudiilinetn
# Knietttthehrenasletlettrandresa
# Rahannnelllericee
# Rarr

# %%
# Set of names, based on a starting set of letters
function newnames(m, alphabet; nnames=10, seed="Ed")
    m = cpu(m)
    Flux.reset!(m)
    buf = IOBuffer()    
    
    for n = 1:nnames
        write(buf, seed)
        c = wsample(alphabet, softmax(m.(map(c -> onehot(c, alphabet), collect(seed)))[end]))
        while c!='\n'
            write(buf, c)
            c = wsample(alphabet, softmax(m(onehot(c, alphabet))))
        end
        write(buf, c) # write out newline to buffer
    end
    return String(take!(buf))
end

newnames(m,alphabet, nnames=100, seed="Ed") |> println
# Out:
# Ededa
# Eds
# Ede
# Edndnensa
# Edn
# Ederrallya
# Ed
# Edhaiorbencne
# Ededorjallmephennnacky
# Edmara
# Eda
# Eder
# Ed
# Edolica
# Edss
# Ede
# Edla
# Edl
# Edarzeli
# Edablas
# Ednnabdpyilen
# Edibemeja
# Edrikobie
# Edlia
# Eddan
# Edy
# Edelemiswa
# Edrrargah
# Eda
# Eda
# Edngra
# Edntaldsn
# Edialarinesspitlh
# Edce
# Edorqo
# Ededagi
# Edsbarlen
# Edryst
# Edsliigberius
# Edeunt
# Edsce
# Edenlkylllledonnnniich
# Edmelatcollelslll
# Ednn
# Edsollarsndninllnnrrarickalch
# Edas
# Edmilrrenndy
# Edrarinndo
# Edafstelllltwadr
# Ed
# Edht
# Edd
# Edshela
# Edlie
# Edyn
# Edndlestertbalnttann
# Edrawthatmevascke
# Edsolesca
# Ed
# Ede
# Edatangnatonnceillwi
# Eddretl
# Edngenlar
# Edrarasnlik
# Ed
# Edla
# Edranr
# Edseikerica
# Ed
# Eda
# Ednet
# Edrasrg
# Edrikannan
# Edoriinstandrra
# Edorn-n
# Edl
# Ed
# Edsdun
# Eddanltinaenarvy
# Eda
# Ed
# Edleledyl
# Eda
# Edramugelsellrth
# Edsterinnorllanrlinzantte
# Edbrih
# Ede
# Edelkelohelettbritta
# Edonina
# Edrce
# Ed
# Ed
# Edita
# Edsssalalandn
# Edffkorinnmvy
# Edalehdn
# Edle
# Edn
# Ednna
# Ederaemlyn
